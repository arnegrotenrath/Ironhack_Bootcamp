# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

plt.style.use('bmh')

# %%
df_real_estate = pd.read_csv("data/20200123_apts_buy_berlin_v0.4_CB.csv", sep=";")

# %%
df_real_estate.head()
# Out:
#    Unnamed: 0         id                                              title  \
# 0           0  114366270  Altersgerechtes Wohnen im Viktoria Quartier! 2...
# 1           1  115294582  EXKLUSIVE NEUBAU-WOHNUNG \nIN RUHIGER KU´DAMM-...
# 2           2  114579519  Wohnen am Bergmannkiez: Moderne 2-Zimmer-Wohnu...
# 3           3  114579517  Wohnen im Neubau: Moderne 2-Zimmer-Wohnung mit...
# 4           4  114579516  Großes Schlafzimmer und Loggia: Gemütliche 2-Z...
#
#      city                    quarter  postcode           street houseNo  \
# 0  Berlin      Kreuzberg (Kreuzberg)     10965              NaN     NaN
# 1  Berlin  Wilmersdorf (Wilmersdorf)     10711              NaN     NaN
# 2  Berlin      Kreuzberg (Kreuzberg)     10961  Baruther Straße       5
# 3  Berlin      Kreuzberg (Kreuzberg)     10961  Baruther Straße       5
# 4  Berlin      Kreuzberg (Kreuzberg)     10961  Baruther Straße       5
#
# ...

# %%
df_real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6755 entries, 0 to 6754
# Data columns (total 18 columns):
# Unnamed: 0       6755 non-null int64
# id               6755 non-null int64
# title            6755 non-null object
# city             6755 non-null object
# quarter          6755 non-null object
# postcode         6755 non-null int64
# street           3615 non-null object
# houseNo          3615 non-null object
# price            6755 non-null float64
# qm               6755 non-null float64
# n_room           6755 non-null float64
# latitude         3607 non-null float64
# longitude        3607 non-null float64
# privateOffer     6755 non-null bool
# marketingType    6755 non-null object
# hasCourtage      6755 non-null object
# n_page_is24      6755 non-null int64
# price_per_qm     6749 non-null float64
# dtypes: bool(1), float64(6), int64(4), object(7)
# memory usage: 903.9+ KB

# %%
# df.count() does not include NaN values
df2 = df_real_estate[[column for column in df_real_estate if df_real_estate[column].count() / len(df_real_estate) >= 0.3]]

print("List of dropped columns:", end=" ")
for c in df_real_estate.columns:
    if c not in df2.columns:
        print(c, end=", ")
print('\n')
#df = df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/code_red/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-ca6e44b4daea> in <module>
# ...
